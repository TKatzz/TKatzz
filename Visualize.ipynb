# %%
import pandas as pd

# %%
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('sample_submission.csv')
test = pd.read_csv('test.csv')
train = pd.read_csv('train.csv')

# %%
sns.heatmap(test.isnull())
# Out:
# <AxesSubplot:>

# %%
sns.heatmap(train.isnull())
# Out:
# <AxesSubplot:>

# %%
sns.countplot(data=train,x='target')
# Out:
# <AxesSubplot:xlabel='target', ylabel='count'>

# %% [markdown]
# So far i see that there is good amount for both classes in 0 and 1, which is good for testing and evaluating the model. However i see that i am missing a lot of values in the location column in both datasets, so i will remove those from the model and remove only the entities where keyword is null since there are not many.

# %%
new_test = test.drop(columns='location',axis=1)

# %%
new_train = train.drop(columns='location',axis=1)

# %%
new_train['keyword'].isnull().sum()
# Out:
# 61

# %%
new_test['keyword'].isnull().sum()
# Out:
# 26

# %% [markdown]
# I can see that i have small amount of missing values in both datasets, so i can go ahead and remove them without removing all the column

# %%
new_test[new_test['keyword'].isnull()]
# Out:
#          id keyword                                               text
# 0         0     NaN                 Just happened a terrible car crash
# 1         2     NaN  Heard about #earthquake is different cities, s...
# 2         3     NaN  there is a forest fire at spot pond, geese are...
# 3         9     NaN           Apocalypse lighting. #Spokane #wildfires
# 4        11     NaN      Typhoon Soudelor kills 28 in China and Taiwan
# 5        12     NaN                 We're shaking...It's an earthquake
# 6        21     NaN  They'd probably still show more life than Arse...
# 7        22     NaN                                  Hey! How are you?
# 8        27     NaN                                   What a nice hat?
# 9        29     NaN                                          Fuck off!
# 10       30     NaN                              No I don't like cold!
# 11       35     NaN                         NOOOOOOOOO! Don't do that!
# ...

# %%
new_test = new_test.dropna()

# %%
new_train = new_train.dropna()

# %%
new_test.to_csv('new_test.csv',index = False)

# %%
new_train.to_csv('new_train.csv',index = False)
